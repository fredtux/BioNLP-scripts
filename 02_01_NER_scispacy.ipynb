# %%
from tqdm import tqdm
import json
import pandas as pd
from pathlib import Path
import numpy as np

import spacy
import scispacy
from scispacy.umls_linking import UmlsEntityLinker
import emoji

# %%
posts_folder = Path('dataset') / 'emetophobia_posts'
with open(posts_folder / 'emetophobia_all_posts_one_label_normalized.json', 'r') as f:
    all_posts = json.load(f)

len(all_posts)
# Out:
# 986

# %%
ner_dir = Path('ner')

# %%
nlp = spacy.load("en_core_sci_md")
# Out:
# /home/tux/Desktop/Master/An1/Sem2/BioNLP/Proiect/venv/lib/python3.12/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
linker = UmlsEntityLinker(resolve_abbreviations=True, filter_for_definitions=False)
# Out:
# /home/tux/Desktop/Master/An1/Sem2/BioNLP/Proiect/venv/lib/python3.12/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.2 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/tux/Desktop/Master/An1/Sem2/BioNLP/Proiect/venv/lib/python3.12/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.2 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
def minimal_normalziation_noemoji(text):
    text = text.replace('\n', ' ')
    text = text.replace('\r', ' ')
    text = emoji.replace_emoji(text, replace='')
    return text.strip()

# %%
for post in tqdm(all_posts):
    doc = nlp(minimal_normalziation_noemoji(post['content']))
    post['entities'] = [(ent, ent._.kb_ents[0][0]) for ent in doc.ents if len(ent._.kb_ents) > 0 and ent._.kb_ents[0][0] in linker.kb.cui_to_entity]
# Out:
#   0%|          | 0/986 [00:00<?, ?it/s]
# 100%|██████████| 986/986 [00:44<00:00, 22.22it/s]

# %% [markdown]
# ## Top entities

# %%
from collections import Counter

# %%
counter = Counter()
for post in tqdm(all_posts):
    for ent, cui in post['entities']:
        counter[cui] += 1
# Out:
# 100%|██████████| 986/986 [00:00<00:00, 155983.24it/s]

# %%
counter.most_common(20)
# Out:
# [('C0212009', 1988),
#  ('C0003467', 471),
#  ('C0221423', 352),
#  ('C0332173', 316),
#  ('C0027497', 313),
#  ('C0038351', 302),
#  ('C0015726', 294),
#  ('C0240526', 188),
#  ('C0027361', 187),
#  ('C0439234', 171),
#  ('C0040364', 164),
#  ('C0013470', 163),
#  ('C0442519', 152),
#  ('C0086769', 147),
#  ('C0439230', 132),
#  ('C0439227', 132),
#  ('C0040223', 131),
#  ('C0349231', 131),
#  ('C0016452', 127),
#  ('C0439228', 121)]

# %%
for cui, count in counter.most_common(20):
    print(f"{linker.kb.cui_to_entity[cui]}=====")
# Out:
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
# CUI: C0038351, Name: Stomach
# Definition: An organ of digestion situated in the left upper quadrant of the abdomen between the termination of the ESOPHAGUS and the beginning of the DUODENUM.
# TUI(s): T023
# Aliases (abbreviated, total: 15):
# 	 Ventriculus, Gastro-, Gastric, gaster, STOMACH, gastric, stomach, gastr(o)-, stomachs, Gastrointestinal Tract, Stomach=====
# CUI: C0015726, Name: Fear (Mental Process)
# Definition: The affective response to an actual current external danger which subsides with the elimination of the threatening condition.
# TUI(s): T041
# Aliases (abbreviated, total: 28):
# 	 scares, scaring, Fear (finding), fright, Fearfulness, fear of, Fright, Fears, Fearful, Fear of=====
# CUI: C0240526, Name: Night time
# Definition: The time in every 24 hour period when it is dark.
# TUI(s): T079
# Aliases (abbreviated, total: 14):
# 	 night, nights, Night Time, night time, at night, Night, NOCTURNAL, At night, on - omni nocte, nocturnal=====
# CUI: C0027361, Name: Persons
# Definition: Persons as individuals (e.g., ABORTION APPLICANTS) or as members of a group (e.g., HISPANIC AMERICANS). It is not used for members of the various professions (e.g., PHYSICIANS) or occupations (e.g., LIBRARIANS) for which OCCUPATIONAL GROUPS is available.
# TUI(s): T098
# Aliases: (total: 9):
# 	 people, Persons, peoples, Person, Person (person), People, Individual, person, persons=====
# CUI: C0439234, Name: year
# Definition: A period of time that it takes for Earth to make a complete revolution around the sun, approximately 365 days; a specific one year period.
# TUI(s): T079
# Aliases: (total: 6):
# 	 year, Year, Annum, years, yr, year (qualifier value)=====
# CUI: C0040364, Name: Toilet Facilities
# Definition: Facilities containing equipment for disposal of human excrement, often with an accompanying hand-washing station.
# TUI(s): T073
# Aliases (abbreviated, total: 11):
# 	 Lavatories, Bathrooms, Facility, Toilet, Lavatory (physical object), Facilities, Toilet, Bathroom, Toilet Facility, Lavatory, Restrooms, Restroom=====
# CUI: C0013470, Name: Eating
# Definition: The consumption of edible substances.
# TUI(s): T040
# Aliases (abbreviated, total: 12):
# 	 eating, Food Intake, food intakes, Eat, Eating, food intake, intakes food, Eating, NOS, Food intake, Intake, Food=====
# CUI: C0442519, Name: Home environment
# Definition: Aspects of peoples' living conditions that may and can impact people's health and/or well-being. These factors may be physical (e.g., housing quality) or social circumstances (e.g., living alone).
# TUI(s): T082
# Aliases (abbreviated, total: 19):
# 	 Dwelling, house, Domestic (environment), Environment, Home, Private home, home environment, Domestic, dwellings, house [environment], Home (environment)=====
# CUI: C0086769, Name: Panic Attacks
# Definition: An episode of intense fear accompanied by symptoms such as heart palpitations, sweating and chills or hot flushes, a sensation of dyspnea, chest pain, abdominal distress, depersonalization, fear of going crazy, and fear of dying.
# TUI(s): T048
# Aliases: (total: 10):
# 	 Attack, Panic, Panic attack, Panic Attacks, Attacks, Panic, panic attacks, Panic attacks, panic attack, Panic attack (finding), Panic Attack, PANIC ATTACKS=====
# CUI: C0439230, Name: week
# Definition: Any period of seven consecutive days.
# TUI(s): T079
# Aliases: (total: 6):
# 	 Weeks, week, Week, week (qualifier value), weeks, wk=====
# CUI: C0439227, Name: Hour
# Definition: A unit measure of time equal to 3,600 seconds or 60 minutes. It is approximately 1/24 of a median day.
# TUI(s): T079
# Aliases: (total: 7):
# 	 h - hour, hours, hr, hrs, hour, Hour, hour (qualifier value)=====
# CUI: C0040223, Name: Time
# Definition: The dimension of the physical universe which, at a given place, orders the sequence of events. (McGraw-Hill Dictionary of Scientific and Technical Terms, 6th ed)
# TUI(s): T079
# Aliases: (total: 10):
# 	 times, Time (attribute), *Time (e.g. seconds), Time, Time Dimension, Time (property) (qualifier value), time, Time (property), Time (e.g. seconds), TIME=====
# CUI: C0349231, Name: Phobic anxiety disorder
# Definition: Anxiety disorders in which the essential feature is persistent and irrational fear of a specific object, activity, or situation that the individual feels compelled to avoid. The individual recognizes the fear as excessive or unreasonable.
# TUI(s): T048
# Aliases (abbreviated, total: 28):
# 	 Phobias, Neuroses, Phobic, Phobic Disorder, phobic neurosis, Phobia NOS, Phobia, PHOBIC NEUROSIS, Neurosis, phobic, phobic disorders, PHOBIC DISORDER=====
# CUI: C0016452, Name: Food
# Definition: Substances taken in by the body to provide nourishment.
# TUI(s): T168
# Aliases: (total: 10):
# 	 Food Product, Food or Food Product, foods, food, Food or Food Substance, FOODS, Food, Foods, Food, NOS, Food (substance)=====
# CUI: C0439228, Name: day
# Definition: The time for Earth to make a complete rotation on its axis; ordinarily divided into twenty-four hours, equal to 86 400 seconds. This also refers to a specific day.
# TUI(s): T079
# Aliases: (total: 7):
# 	 d - day, d day, Day, Days, day, day (qualifier value), days=====

# %% [markdown]
# ## Top entities per label

# %%
labels = set()
for post in tqdm(all_posts):
    labels.update([post['labels']])
labels
# Out:
# 100%|██████████| 986/986 [00:00<00:00, 1623070.54it/s]
# {'Does Anyone Else...?',
#  'Interesting info/Articles',
#  'It Happened (TW)',
#  'Moderator',
#  'Needing Support - Anxious about FP',
#  'Needing Support - In Acute Crisis (at risk of self injury)',
#  'Needing Support - N, V, D etc',
#  'Needing Support - N, V, D etc NO REASSURANCE',
#  'Needing Support - Non-Emet related',
#  'Needing support - Panic attack',
#  'Needing support: Just not feeling good',
#  'None',
#  'Positive Reminder',
#  'Potentially Triggering',
#  'Question',
#  'Rant',
#  'Recovery',
#  'Success!',
#  'Techniques, tips and tricks',
#  'Therapy info!',
#  'Venting - Advice wanted',
#  'Venting - No advice please'}

# %%
for label in labels:
    print(label)
    lbl_counter = Counter()
    for post in all_posts:
        if label in post['labels']:
            for ent, cui in post['entities']:
                lbl_counter[cui] += 1
    print(lbl_counter.most_common(5))

    for cui, count in lbl_counter.most_common(5):
        print(f"{linker.kb.cui_to_entity[cui]}=====")
    print('\n\n')
# Out:
# Does Anyone Else...?
# [('C0212009', 192), ('C0003467', 62), ('C0221423', 33), ('C0027497', 28), ('C0038351', 22)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
# CUI: C0038351, Name: Stomach
# Definition: An organ of digestion situated in the left upper quadrant of the abdomen between the termination of the ESOPHAGUS and the beginning of the DUODENUM.
# TUI(s): T023
# Aliases (abbreviated, total: 15):
# 	 Ventriculus, Gastro-, Gastric, gaster, STOMACH, gastric, stomach, gastr(o)-, stomachs, Gastrointestinal Tract, Stomach=====
#
#
#
# Techniques, tips and tricks
# [('C0212009', 50), ('C0003467', 25), ('C0013227', 8), ('C0162751', 8), ('C0332173', 7)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0013227, Name: Pharmaceutical Preparations
# Definition: Drugs intended for human or veterinary use, presented in their finished dosage form. Included here are materials used in the preparation and/or formulation of the finished dosage form.
# TUI(s): T121
# Aliases (abbreviated, total: 39):
# 	 Drug/agent, drugs, Preparations, Pharmaceutic, Medicinal product (product), Medication, NOS, Drug preparation, NOS, Drug Product, Drug or medicament, medication, Medicine=====
# CUI: C0162751, Name: Ginger (dietary)
# Definition: A fresh, dried or processed form of the rhizome of the Asian perennial plant Zingiber officinale (ginger) with potential anti-emetic activity. Ginger is mainly used in cooking due to its unique fragrance and flavor and has been studied for its use in the treatment of nausea and vomiting. The gingeroles and shoagoles found in ginger may be responsible for ginger's anti-emetic effect.
# TUI(s): T168
# Aliases: (total: 7):
# 	 gingers, Ginger (substance), Ginger, Ginger Root, zingiber officinale, Ginger Rhizome, ginger=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
#
#
#
# Needing Support - Anxious about FP
# [('C0212009', 42), ('C0037361', 11), ('C0016479', 9), ('C0039336', 9), ('C0003467', 9)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0037361, Name: Smell Perception
# Definition: The ability to detect scents or odors, such as the function of OLFACTORY RECEPTOR NEURONS.
# TUI(s): T040
# Aliases (abbreviated, total: 21):
# 	 Olfaction, NOS, smell perception, Smell Sense, smell sense, Sense of smell, function (observable entity), Sense of smell, function, smell, smelling, smelled, Olfactory=====
# CUI: C0016479, Name: Food Poisoning
# Definition: Any disorder that results from the consumption of food contaminated with an infectious agent or toxin.
# TUI(s): T037
# Aliases (abbreviated, total: 11):
# 	 Food Poisonings, FOOD POISONING, Food Poisoning, Food poisoning, NOS, Food poisoning, unspecified, Food poisoning (disorder), Food poisoning, Foodborne Illness, FP - Food poisoning, food poisoning=====
# CUI: C0039336, Name: Taste Perception
# Definition: The ability to detect chemicals through gustatory receptors in the mouth, including those on the TONGUE; the PALATE; the PHARYNX; and the EPIGLOTTIS.
# TUI(s): T042
# Aliases (abbreviated, total: 28):
# 	 taste sensation, Senses, Taste, Taste, function, taste sense, Finding of sense of taste (finding), taste perception, Finding of sense of taste, Taste, tastes, sense of taste=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
#
#
#
# Success!
# [('C0212009', 134), ('C0015726', 28), ('C0439234', 26), ('C0332173', 24), ('C0003467', 20)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0015726, Name: Fear (Mental Process)
# Definition: The affective response to an actual current external danger which subsides with the elimination of the threatening condition.
# TUI(s): T041
# Aliases (abbreviated, total: 28):
# 	 scares, scaring, Fear (finding), fright, Fearfulness, fear of, Fright, Fears, Fearful, Fear of=====
# CUI: C0439234, Name: year
# Definition: A period of time that it takes for Earth to make a complete revolution around the sun, approximately 365 days; a specific one year period.
# TUI(s): T079
# Aliases: (total: 6):
# 	 year, Year, Annum, years, yr, year (qualifier value)=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
#
#
#
# Interesting info/Articles
# [('C0212009', 3), ('C0042655', 2), ('C0221423', 2), ('C0038841', 2), ('C0349231', 1)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0042655, Name: videocassette
# Definition: None
# TUI(s): T073
# Aliases (abbreviated, total: 13):
# 	 Videotapes, Video, Video (physical object), videocassette, video tape, videotapes, videos, Video tapes, Videotape, video=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0038841, Name: Superstitions
# Definition: A belief or practice which lacks adequate basis for proof; an embodiment of fear of the unknown, magic, and ignorance.
# TUI(s): T078
# Aliases: (total: 3):
# 	 superstition, Superstition, superstitions=====
# CUI: C0349231, Name: Phobic anxiety disorder
# Definition: Anxiety disorders in which the essential feature is persistent and irrational fear of a specific object, activity, or situation that the individual feels compelled to avoid. The individual recognizes the fear as excessive or unreasonable.
# TUI(s): T048
# Aliases (abbreviated, total: 28):
# 	 Phobias, Neuroses, Phobic, Phobic Disorder, phobic neurosis, Phobia NOS, Phobia, PHOBIC NEUROSIS, Neurosis, phobic, phobic disorders, PHOBIC DISORDER=====
#
#
#
# Venting - Advice wanted
# [('C0212009', 125), ('C0003467', 42), ('C0332173', 30), ('C0221423', 23), ('C0027497', 20)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
#
#
#
# Venting - No advice please
# [('C0086769', 3), ('C0040364', 3), ('C0337576', 3), ('C0086582', 2), ('C0337580', 2)]
# CUI: C0086769, Name: Panic Attacks
# Definition: An episode of intense fear accompanied by symptoms such as heart palpitations, sweating and chills or hot flushes, a sensation of dyspnea, chest pain, abdominal distress, depersonalization, fear of going crazy, and fear of dying.
# TUI(s): T048
# Aliases: (total: 10):
# 	 Attack, Panic, Panic attack, Panic Attacks, Attacks, Panic, panic attacks, Panic attacks, panic attack, Panic attack (finding), Panic Attack, PANIC ATTACKS=====
# CUI: C0040364, Name: Toilet Facilities
# Definition: Facilities containing equipment for disposal of human excrement, often with an accompanying hand-washing station.
# TUI(s): T073
# Aliases (abbreviated, total: 11):
# 	 Lavatories, Bathrooms, Facility, Toilet, Lavatory (physical object), Facilities, Toilet, Bathroom, Toilet Facility, Lavatory, Restrooms, Restroom=====
# CUI: C0337576, Name: Aunt
# Definition: The sister of your father or mother; the wife of your uncle.
# TUI(s): T099
# Aliases: (total: 4):
# 	 Aunt (person), Aunt, aunt, aunts=====
# CUI: C0086582, Name: Males
# Definition: A person who belongs to the sex that normally produces sperm. The term is used to indicate biological sex distinctions, cultural gender role distinctions, or both.
# TUI(s): T032
# Aliases (abbreviated, total: 21):
# 	 Male individual, Male structure, Male, Sex Male, Male structure (body structure), Human Males, MAN, human male, MALE SEX, Male, NOS=====
# CUI: C0337580, Name: Cousin
# Definition: A child of your aunt or uncle or their descendents.
# TUI(s): T099
# Aliases: (total: 5):
# 	 Cousin, Cousin (person), cousin, cousins, Cousin, NOS=====
#
#
#
# Needing support - Panic attack
# [('C0212009', 279), ('C0003467', 56), ('C0038351', 55), ('C0221423', 55), ('C0027497', 44)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0038351, Name: Stomach
# Definition: An organ of digestion situated in the left upper quadrant of the abdomen between the termination of the ESOPHAGUS and the beginning of the DUODENUM.
# TUI(s): T023
# Aliases (abbreviated, total: 15):
# 	 Ventriculus, Gastro-, Gastric, gaster, STOMACH, gastric, stomach, gastr(o)-, stomachs, Gastrointestinal Tract, Stomach=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
#
#
#
# Question
# [('C0212009', 265), ('C0221423', 64), ('C0003467', 61), ('C0027497', 41), ('C0027361', 39)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
# CUI: C0027361, Name: Persons
# Definition: Persons as individuals (e.g., ABORTION APPLICANTS) or as members of a group (e.g., HISPANIC AMERICANS). It is not used for members of the various professions (e.g., PHYSICIANS) or occupations (e.g., LIBRARIANS) for which OCCUPATIONAL GROUPS is available.
# TUI(s): T098
# Aliases: (total: 9):
# 	 people, Persons, peoples, Person, Person (person), People, Individual, person, persons=====
#
#
#
# It Happened (TW)
# [('C0212009', 37), ('C0038351', 11), ('C0332173', 11), ('C0027497', 7), ('C0439234', 7)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0038351, Name: Stomach
# Definition: An organ of digestion situated in the left upper quadrant of the abdomen between the termination of the ESOPHAGUS and the beginning of the DUODENUM.
# TUI(s): T023
# Aliases (abbreviated, total: 15):
# 	 Ventriculus, Gastro-, Gastric, gaster, STOMACH, gastric, stomach, gastr(o)-, stomachs, Gastrointestinal Tract, Stomach=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
# CUI: C0439234, Name: year
# Definition: A period of time that it takes for Earth to make a complete revolution around the sun, approximately 365 days; a specific one year period.
# TUI(s): T079
# Aliases: (total: 6):
# 	 year, Year, Annum, years, yr, year (qualifier value)=====
#
#
#
# Positive Reminder
# [('C0212009', 12), ('C0086769', 5), ('C2584314', 5), ('C4054119', 4), ('C0003467', 4)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0086769, Name: Panic Attacks
# Definition: An episode of intense fear accompanied by symptoms such as heart palpitations, sweating and chills or hot flushes, a sensation of dyspnea, chest pain, abdominal distress, depersonalization, fear of going crazy, and fear of dying.
# TUI(s): T048
# Aliases: (total: 10):
# 	 Attack, Panic, Panic attack, Panic Attacks, Attacks, Panic, panic attacks, Panic attacks, panic attack, Panic attack (finding), Panic Attack, PANIC ATTACKS=====
# CUI: C2584314, Name: Throwing
# Definition: None
# TUI(s): T040
# Aliases: (total: 3):
# 	 throw, throws, throwing=====
# CUI: C4054119, Name: Rating Myself
# Definition: A question about an individual's total assessment of their abilities.
# TUI(s): T170
# Aliases: (total: 1):
# 	 Self Rating=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
#
#
#
# Needing Support - N, V, D etc NO REASSURANCE
# [('C0032930', 4), ('C0027497', 2), ('C0016452', 2), ('C0439234', 2), ('C0212009', 2)]
# CUI: C0032930, Name: Precipitating Factors
# Definition: Factors associated with the definitive onset of a disease, illness, accident, behavioral response, or course of action. Usually one factor is more important or more obviously recognizable than others, if several are involved, and one may often be regarded as "necessary". Examples include exposure to specific disease; amount or level of an infectious organism, drug, or noxious agent, etc.
# TUI(s): T201
# Aliases (abbreviated, total: 11):
# 	 Factor, Precipitating, precipitating factor, trigger, triggers, Precipitating Factor, Factors, Precipitating, Precipitating factor, triggering factor, Provoking factor, precipitating factors=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
# CUI: C0016452, Name: Food
# Definition: Substances taken in by the body to provide nourishment.
# TUI(s): T168
# Aliases: (total: 10):
# 	 Food Product, Food or Food Product, foods, food, Food or Food Substance, FOODS, Food, Foods, Food, NOS, Food (substance)=====
# CUI: C0439234, Name: year
# Definition: A period of time that it takes for Earth to make a complete revolution around the sun, approximately 365 days; a specific one year period.
# TUI(s): T079
# Aliases: (total: 6):
# 	 year, Year, Annum, years, yr, year (qualifier value)=====
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
#
#
#
# Therapy info!
# [('C1537436', 2), ('C1883016', 2), ('C0525726', 2), ('C0282411', 1), ('C0871525', 1)]
# CUI: C1537436, Name: KCNQ1DN gene
# Definition: None
# TUI(s): T028
# Aliases: (total: 7):
# 	 KCNQ1DN, KCNQ1 DOWNSTREAM NEIGHBOR, KCNQ1DN gene, HSA404617, KCNQ1 downstream neighbor (non-protein coding), BWRT, KCNQ1 downstream neighbor=====
# CUI: C1883016, Name: Activity Session
# Definition: Time, period, or term devoted to some activity.
# TUI(s): T051
# Aliases: (total: 1):
# 	 Session=====
# CUI: C0525726, Name: Remeron
# Definition: None
# TUI(s): T109, T121
# Aliases: (total: 3):
# 	 Remeron, remeron, Remergil=====
# CUI: C0282411, Name: Published Comment
# Definition: Work consisting of a critical or explanatory note written to discuss, support, or dispute an article or other presentation previously published. It may take the form of an article, letter, editorial, etc. It appears in publications under a variety of names: comment, commentary, editorial comment, viewpoint, etc.
# TUI(s): T170
# Aliases (abbreviated, total: 12):
# 	 Comment, viewpoints, Remarks, comments, Viewpoint, Remark, viewpoint, Commentary, Comments, comment=====
# CUI: C0871525, Name: therapist
# Definition: None
# TUI(s): T097
# Aliases: (total: 1):
# 	 therapists=====
#
#
#
# Needing Support - In Acute Crisis (at risk of self injury)
# [('C0212009', 75), ('C0038351', 23), ('C0015726', 22), ('C0221423', 17), ('C0027497', 14)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0038351, Name: Stomach
# Definition: An organ of digestion situated in the left upper quadrant of the abdomen between the termination of the ESOPHAGUS and the beginning of the DUODENUM.
# TUI(s): T023
# Aliases (abbreviated, total: 15):
# 	 Ventriculus, Gastro-, Gastric, gaster, STOMACH, gastric, stomach, gastr(o)-, stomachs, Gastrointestinal Tract, Stomach=====
# CUI: C0015726, Name: Fear (Mental Process)
# Definition: The affective response to an actual current external danger which subsides with the elimination of the threatening condition.
# TUI(s): T041
# Aliases (abbreviated, total: 28):
# 	 scares, scaring, Fear (finding), fright, Fearfulness, fear of, Fright, Fears, Fearful, Fear of=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
#
#
#
# Recovery
# [('C0212009', 44), ('C0332173', 12), ('C0015726', 7), ('C0349231', 7), ('C0027497', 6)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
# CUI: C0015726, Name: Fear (Mental Process)
# Definition: The affective response to an actual current external danger which subsides with the elimination of the threatening condition.
# TUI(s): T041
# Aliases (abbreviated, total: 28):
# 	 scares, scaring, Fear (finding), fright, Fearfulness, fear of, Fright, Fears, Fearful, Fear of=====
# CUI: C0349231, Name: Phobic anxiety disorder
# Definition: Anxiety disorders in which the essential feature is persistent and irrational fear of a specific object, activity, or situation that the individual feels compelled to avoid. The individual recognizes the fear as excessive or unreasonable.
# TUI(s): T048
# Aliases (abbreviated, total: 28):
# 	 Phobias, Neuroses, Phobic, Phobic Disorder, phobic neurosis, Phobia NOS, Phobia, PHOBIC NEUROSIS, Neurosis, phobic, phobic disorders, PHOBIC DISORDER=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
#
#
#
# None
# [('C0023185', 17), ('C0015726', 12), ('C0027361', 11), ('C0339897', 11), ('C0033119', 11)]
# CUI: C0023185, Name: Learning
# Definition: Relatively permanent change in behavior that is the result of past experience or practice. The concept includes the acquisition of knowledge.
# TUI(s): T041
# Aliases: (total: 7):
# 	 Learning, function (observable entity), learned, learn, Learning, NOS, learning, Learning, function, Learning=====
# CUI: C0015726, Name: Fear (Mental Process)
# Definition: The affective response to an actual current external danger which subsides with the elimination of the threatening condition.
# TUI(s): T041
# Aliases (abbreviated, total: 28):
# 	 scares, scaring, Fear (finding), fright, Fearfulness, fear of, Fright, Fears, Fearful, Fear of=====
# CUI: C0027361, Name: Persons
# Definition: Persons as individuals (e.g., ABORTION APPLICANTS) or as members of a group (e.g., HISPANIC AMERICANS). It is not used for members of the various professions (e.g., PHYSICIANS) or occupations (e.g., LIBRARIANS) for which OCCUPATIONAL GROUPS is available.
# TUI(s): T098
# Aliases: (total: 9):
# 	 people, Persons, peoples, Person, Person (person), People, Individual, person, persons=====
# CUI: C0339897, Name: Transjugular intrahepatic portosystemic shunt procedure
# Definition: A type of surgical portasystemic shunt to reduce portal hypertension with associated complications of esophageal varices and ascites. It is performed percutaneously through the jugular vein and involves the creation of an intrahepatic shunt between the hepatic vein and portal vein. The channel is maintained by a metallic stent. The procedure can be performed in patients who have failed sclerotherapy and is an additional option to the surgical techniques of portocaval, mesocaval, and splenorenal shunts. It takes one to three hours to perform. (JAMA 1995;273(23):1824-30)
# TUI(s): T061
# Aliases (abbreviated, total: 11):
# 	 Portosystemic Shunt, Transjugular Intrahepatic, Shunt, Transjugular Intrahepatic Portosystemic, Transjugular intrahepatic portosystemic shunt (procedure), TIPSS, Transjugular intrahepatic portosystemic shunt, TIPS - Transjugular intrahepatic portosystemic shunt, Transjugular Intrahepatic Portosystemic Shunt, TIPS, Transjugular Intrahepatic Portasystemic Shunt, Portasystemic Shunt, Transjugular Intrahepatic=====
# CUI: C0033119, Name: Puncture wound
# Definition: Disruption of tissue caused by a pointed object.
# TUI(s): T037
# Aliases (abbreviated, total: 17):
# 	 PUNCTURE WOUND, PUNCTURES, Puncture (morphologic abnormality), Punctured, Prick, Puncture wound - injury (disorder), puncture wound, punctures, prick, Puncture, NOS=====
#
#
#
# Needing Support - N, V, D etc
# [('C0212009', 66), ('C0038351', 21), ('C0003467', 17), ('C0332173', 17), ('C0027497', 15)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0038351, Name: Stomach
# Definition: An organ of digestion situated in the left upper quadrant of the abdomen between the termination of the ESOPHAGUS and the beginning of the DUODENUM.
# TUI(s): T023
# Aliases (abbreviated, total: 15):
# 	 Ventriculus, Gastro-, Gastric, gaster, STOMACH, gastric, stomach, gastr(o)-, stomachs, Gastrointestinal Tract, Stomach=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
#
#
#
# Moderator
# [('C0003467', 10), ('C0349231', 5), ('C0679006', 4), ('C0237820', 4), ('C0009462', 4)]
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0349231, Name: Phobic anxiety disorder
# Definition: Anxiety disorders in which the essential feature is persistent and irrational fear of a specific object, activity, or situation that the individual feels compelled to avoid. The individual recognizes the fear as excessive or unreasonable.
# TUI(s): T048
# Aliases (abbreviated, total: 28):
# 	 Phobias, Neuroses, Phobic, Phobic Disorder, phobic neurosis, Phobia NOS, Phobia, PHOBIC NEUROSIS, Neurosis, phobic, phobic disorders, PHOBIC DISORDER=====
# CUI: C0679006, Name: Decision
# Definition: A position, opinion, or judgment reached on an issue under consideration.
# TUI(s): T041
# Aliases: (total: 4):
# 	 decisions, decision, Decision, Call=====
# CUI: C0237820, Name: Recovery - action
# Definition: A getting back or regaining.
# TUI(s): T052
# Aliases: (total: 6):
# 	 recovery, Recovery, Salvage, recoveries, disease recovery, disorder recovery=====
# CUI: C0009462, Name: Community
# Definition: A set of people with some shared element. The substance of shared element varies widely, from geography to a situation to interest to lives and values. The term is widely used to evoke sense of collectivity.
# TUI(s): T096
# Aliases: (total: 6):
# 	 communities, community, Communities, ^Community, Community, Community (social concept)=====
#
#
#
# Needing Support - Non-Emet related
# [('C0212009', 13), ('C0013470', 5), ('C0439231', 4), ('C0013227', 3), ('C0016452', 3)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0013470, Name: Eating
# Definition: The consumption of edible substances.
# TUI(s): T040
# Aliases (abbreviated, total: 12):
# 	 eating, Food Intake, food intakes, Eat, Eating, food intake, intakes food, Eating, NOS, Food intake, Intake, Food=====
# CUI: C0439231, Name: month
# Definition: One of the 12 divisions of a year as determined by a calendar. It corresponds to the unit of time of approximately to one cycle of the moon's phases, about 30 days or 4 weeks.
# TUI(s): T079
# Aliases: (total: 5):
# 	 month (qualifier value), months, Months, month, Month=====
# CUI: C0013227, Name: Pharmaceutical Preparations
# Definition: Drugs intended for human or veterinary use, presented in their finished dosage form. Included here are materials used in the preparation and/or formulation of the finished dosage form.
# TUI(s): T121
# Aliases (abbreviated, total: 39):
# 	 Drug/agent, drugs, Preparations, Pharmaceutic, Medicinal product (product), Medication, NOS, Drug preparation, NOS, Drug Product, Drug or medicament, medication, Medicine=====
# CUI: C0016452, Name: Food
# Definition: Substances taken in by the body to provide nourishment.
# TUI(s): T168
# Aliases: (total: 10):
# 	 Food Product, Food or Food Product, foods, food, Food or Food Substance, FOODS, Food, Foods, Food, NOS, Food (substance)=====
#
#
#
# Rant
# [('C0212009', 277), ('C0003467', 75), ('C0221423', 66), ('C0332173', 56), ('C0027497', 55)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
#
#
#
# Potentially Triggering
# [('C0212009', 218), ('C0015726', 41), ('C0221423', 37), ('C0003467', 29), ('C0332173', 29)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0015726, Name: Fear (Mental Process)
# Definition: The affective response to an actual current external danger which subsides with the elimination of the threatening condition.
# TUI(s): T041
# Aliases (abbreviated, total: 28):
# 	 scares, scaring, Fear (finding), fright, Fearfulness, fear of, Fright, Fears, Fearful, Fear of=====
# CUI: C0221423, Name: Illness (finding)
# Definition: A state of ill health, bodily malfunction, or discomfort.
# TUI(s): T184
# Aliases (abbreviated, total: 13):
# 	 sicknesses, sickness, Illness, NOS, Illness (finding), Sickness, ailments, feeling ill, Sick, Illness, illnesses=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====
#
#
#
# Needing support: Just not feeling good
# [('C0212009', 152), ('C0038351', 37), ('C0003467', 36), ('C0027497', 33), ('C0332173', 26)]
# CUI: C0212009, Name: I-antigen
# Definition: None
# TUI(s): T116, T129
# Aliases (abbreviated, total: 12):
# 	 I BLOOD GROUP ANTIGENS, Blood group antigen I, I antigen, I, Blood group antigen I (substance), I Antigen, I-antigen, Blood group antigen I, NOS, I NOS Ag, I Ag=====
# CUI: C0038351, Name: Stomach
# Definition: An organ of digestion situated in the left upper quadrant of the abdomen between the termination of the ESOPHAGUS and the beginning of the DUODENUM.
# TUI(s): T023
# Aliases (abbreviated, total: 15):
# 	 Ventriculus, Gastro-, Gastric, gaster, STOMACH, gastric, stomach, gastr(o)-, stomachs, Gastrointestinal Tract, Stomach=====
# CUI: C0003467, Name: Anxiety
# Definition: Feelings or emotions of dread, apprehension, and impending disaster but not disabling as with ANXIETY DISORDERS.
# TUI(s): T048
# Aliases (abbreviated, total: 21):
# 	 anxious, Angst, anxieties, Anxiety, Anxiety Reaction, Feel anxious, Excessive, persistent worry and fear, unfocused anxiety, Anxiety (finding), angst=====
# CUI: C0027497, Name: Nausea
# Definition: An unpleasant sensation in the stomach usually accompanied by the urge to vomit. Common causes are early pregnancy, sea and motion sickness, emotional stress, intense pain, food poisoning, and various enteroviruses.
# TUI(s): T184
# Aliases (abbreviated, total: 21):
# 	 NAUSEA, symptom nausea, sick feeling, nauseated, Nauseated, nauseous, nauseating, nauseas, nausea, Nauseous=====
# CUI: C0332173, Name: Daily
# Definition: Occurring or done each day.
# TUI(s): T079
# Aliases (abbreviated, total: 12):
# 	 Every Day, daily, quaque die, each day, Daily, Day, QD, every day, Every day, Each day=====

# %% [markdown]
# ## Total entities per label

# %%
for label in labels:
    lbl_counter = 0
    for post in all_posts:
        if label in post['labels']:
            lbl_counter += len(post['entities'])
    
    print(f"{label}: {lbl_counter} entities")
# Out:
# Does Anyone Else...?: 1407 entities
# Techniques, tips and tricks: 461 entities
# Needing Support - Anxious about FP: 453 entities
# Success!: 1122 entities
# Interesting info/Articles: 21 entities
# Venting - Advice wanted: 1040 entities
# Venting - No advice please: 46 entities
# Needing support - Panic attack: 2504 entities
# Question: 2581 entities
# It Happened (TW): 362 entities
# Positive Reminder: 221 entities
# Needing Support - N, V, D etc NO REASSURANCE: 72 entities
# Therapy info!: 28 entities
# Needing Support - In Acute Crisis (at risk of self injury): 713 entities
# Recovery: 342 entities
# None: 169 entities
# Needing Support - N, V, D etc: 667 entities
# Moderator: 160 entities
# Needing Support - Non-Emet related: 106 entities
# Rant: 2616 entities
# Potentially Triggering: 1849 entities
# Needing support: Just not feeling good: 1240 entities

# %% [markdown]
# ## Statistics entities per post

# %%
all_num_entities = []

for post in tqdm(all_posts):
    all_num_entities.append(len(post['entities']))

all_num_entities = np.array(all_num_entities)
print(f"Mean number of entities per post: {np.mean(all_num_entities)}")
print(f"Median number of entities per post: {np.median(all_num_entities)}")
print(f"Max number of entities per post: {np.max(all_num_entities)}")
print(f"Min number of entities per post: {np.min(all_num_entities)}")
print(f"Stdev number of entities per post: {np.std(all_num_entities)}")
# Out:
# 100%|██████████| 986/986 [00:00<00:00, 2355116.03it/s]
# Mean number of entities per post: 18.365111561866126
# Median number of entities per post: 14.0
# Max number of entities per post: 160
# Min number of entities per post: 0
# Stdev number of entities per post: 16.834493223950325

# %% [markdown]
# ## Statistics entities per label

# %%
lbl_dict = {}

for label in labels:
    print(label)
    lbl_num_entities = []
    for post in all_posts:
        if label in post['labels']:
            lbl_num_entities.append(len(post['entities']))
    lbl_num_entities = np.array(lbl_num_entities)

    lbl_dict[label] = {
        'mean': np.mean(lbl_num_entities),
        'median': np.median(lbl_num_entities),
        'max': np.max(lbl_num_entities),
        'min': np.min(lbl_num_entities),
        'stdev': np.std(lbl_num_entities),
        'num_posts': len(lbl_num_entities)
    }

    print(f"Mean number of entities per post: {np.mean(lbl_num_entities)}")
    print(f"Median number of entities per post: {np.median(lbl_num_entities)}")
    print(f"Max number of entities per post: {np.max(lbl_num_entities)}")
    print(f"Min number of entities per post: {np.min(lbl_num_entities)}")
    print(f"Stdev number of entities per post: {np.std(lbl_num_entities)}")
    print("\n\n")
# Out:
# Does Anyone Else...?
# Mean number of entities per post: 18.03846153846154
# Median number of entities per post: 14.5
# Max number of entities per post: 53
# Min number of entities per post: 1
# Stdev number of entities per post: 13.112376525479908
#
#
#
# Techniques, tips and tricks
# Mean number of entities per post: 25.61111111111111
# Median number of entities per post: 13.0
# Max number of entities per post: 85
# Min number of entities per post: 3
# Stdev number of entities per post: 25.351175490801843
#
#
#
# Needing Support - Anxious about FP
# Mean number of entities per post: 14.612903225806452
# Median number of entities per post: 13.0
# Max number of entities per post: 44
# Min number of entities per post: 1
# Stdev number of entities per post: 9.690958271318745
#
#
#
# Success!
# Mean number of entities per post: 29.526315789473685
# Median number of entities per post: 22.0
# Max number of entities per post: 119
# Min number of entities per post: 1
# Stdev number of entities per post: 24.419294401316588
#
#
#
# Interesting info/Articles
# Mean number of entities per post: 7.0
# Median number of entities per post: 6.0
# Max number of entities per post: 14
# Min number of entities per post: 1
# Stdev number of entities per post: 5.354126134736337
#
#
#
# Venting - Advice wanted
# Mean number of entities per post: 24.761904761904763
# Median number of entities per post: 17.5
# Max number of entities per post: 83
# Min number of entities per post: 1
# Stdev number of entities per post: 20.45414095204606
#
#
#
# Venting - No advice please
# Mean number of entities per post: 46.0
# Median number of entities per post: 46.0
# Max number of entities per post: 46
# Min number of entities per post: 46
# Stdev number of entities per post: 0.0
#
#
#
# Needing support - Panic attack
# Mean number of entities per post: 16.582781456953644
# Median number of entities per post: 14.0
# Max number of entities per post: 52
# Min number of entities per post: 0
# Stdev number of entities per post: 10.750239557407218
#
#
#
# Question
# Mean number of entities per post: 13.373056994818652
# Median number of entities per post: 11.0
# Max number of entities per post: 72
# Min number of entities per post: 0
# Stdev number of entities per post: 10.65549552837881
#
#
#
# It Happened (TW)
# Mean number of entities per post: 30.166666666666668
# Median number of entities per post: 22.5
# Max number of entities per post: 86
# Min number of entities per post: 6
# Stdev number of entities per post: 23.7480993391518
#
#
#
# Positive Reminder
# Mean number of entities per post: 44.2
# Median number of entities per post: 43.0
# Max number of entities per post: 93
# Min number of entities per post: 9
# Stdev number of entities per post: 28.074187432586537
#
#
#
# Needing Support - N, V, D etc NO REASSURANCE
# Mean number of entities per post: 24.0
# Median number of entities per post: 18.0
# Max number of entities per post: 38
# Min number of entities per post: 16
# Stdev number of entities per post: 9.93310961716756
#
#
#
# Therapy info!
# Mean number of entities per post: 9.333333333333334
# Median number of entities per post: 9.0
# Max number of entities per post: 15
# Min number of entities per post: 4
# Stdev number of entities per post: 4.4969125210773475
#
#
#
# Needing Support - In Acute Crisis (at risk of self injury)
# Mean number of entities per post: 15.844444444444445
# Median number of entities per post: 14.0
# Max number of entities per post: 46
# Min number of entities per post: 1
# Stdev number of entities per post: 9.586925252784082
#
#
#
# Recovery
# Mean number of entities per post: 31.09090909090909
# Median number of entities per post: 15.0
# Max number of entities per post: 102
# Min number of entities per post: 5
# Stdev number of entities per post: 32.337578886868805
#
#
#
# None
# Mean number of entities per post: 10.5625
# Median number of entities per post: 10.0
# Max number of entities per post: 14
# Min number of entities per post: 7
# Stdev number of entities per post: 2.9148059540902547
#
#
#
# Needing Support - N, V, D etc
# Mean number of entities per post: 15.511627906976743
# Median number of entities per post: 14.0
# Max number of entities per post: 51
# Min number of entities per post: 2
# Stdev number of entities per post: 10.155470728726064
#
#
#
# Moderator
# Mean number of entities per post: 160.0
# Median number of entities per post: 160.0
# Max number of entities per post: 160
# Min number of entities per post: 160
# Stdev number of entities per post: 0.0
#
#
#
# Needing Support - Non-Emet related
# Mean number of entities per post: 26.5
# Median number of entities per post: 27.5
# Max number of entities per post: 43
# Min number of entities per post: 8
# Stdev number of entities per post: 13.009611831257688
#
#
#
# Rant
# Mean number of entities per post: 19.52238805970149
# Median number of entities per post: 15.0
# Max number of entities per post: 120
# Min number of entities per post: 0
# Stdev number of entities per post: 17.918853748783853
#
#
#
# Potentially Triggering
# Mean number of entities per post: 22.011904761904763
# Median number of entities per post: 16.0
# Max number of entities per post: 156
# Min number of entities per post: 1
# Stdev number of entities per post: 22.140511268464984
#
#
#
# Needing support: Just not feeling good
# Mean number of entities per post: 16.986301369863014
# Median number of entities per post: 13.0
# Max number of entities per post: 52
# Min number of entities per post: 1
# Stdev number of entities per post: 12.449892061681997

# %%
df_lbl_scispacy = pd.DataFrame.from_dict(lbl_dict, orient='index')

df_lbl_scispacy.to_excel(ner_dir / 'emetophobia_labels_ner_scispacy.xlsx', index=True, index_label='label')

# %%
all_serializable_posts = []

for post in tqdm(all_posts):
    new_post = post.copy()
    new_ents = []
    for ent in new_post['entities']:
        new_ents.append([ent[0].text, ent[1]])
    new_post['entities'] = new_ents
    all_serializable_posts.append(new_post)

len(all_serializable_posts)
# Out:
# 100%|██████████| 986/986 [00:00<00:00, 30474.58it/s]
# 986

# %%
with open(ner_dir / 'emetophobia_posts_ner_scispacy.json', 'w') as f:
    json.dump(all_serializable_posts, f, indent=4)

# %% [markdown]
# ## Posts with 0 entities

# %%
posts_0_ents = []

for post in tqdm(all_posts):
    if len(post['entities']) == 0:
        posts_0_ents.append(post['content'])

len(posts_0_ents)
# Out:
# 100%|██████████| 986/986 [00:00<00:00, 2634129.77it/s]
# 10

# %%
df_posts_0_ents = pd.DataFrame(posts_0_ents, columns=['content'])
df_posts_0_ents.to_excel(ner_dir / 'emetophobia_posts_0_entities_scispacy.xlsx', index=False)
